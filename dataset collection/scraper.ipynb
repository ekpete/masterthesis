# %%
#!pip install selenium

# %%
#!pip install webdriver-manager

# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
import urllib
import time
from selenium import webdriver 
from selenium.webdriver.common.by import By 
from selenium.webdriver.chrome.service import Service as ChromeService 
from webdriver_manager.chrome import ChromeDriverManager 
 
# instantiate options 
options = webdriver.ChromeOptions() 
 
# run browser in headless mode 
options.headless = True 
 
# instantiate driver 
driver = webdriver.Chrome(service=ChromeService( 
	ChromeDriverManager().install()), options=options) 

# range is number of pages
for i in range(1):
    # load website 
    url = f'https://hello.eboy.com/pool/everything/{i}' 

    # get the entire website content 
    driver.get(url) 

    driver.maximize_window() # For maximizing window
    driver.implicitly_wait(2) # gives an implicit wait for 2 seconds


    imgResults = driver.find_elements(By.XPATH,("//img[contains(@src,'.png')]"));
    # Access and store the scr list of image url's.
    src = []
    for img in imgResults:
        src.append(img.get_attribute('src'))

    for j, image in enumerate(src):
        print(image)
        img_data = requests.get(image).content
        with open(f'{i}_{j}.png', 'wb') as handler:
            handler.write(img_data)
# Out:
# /var/folders/tk/xvpdvwrx2vbbfy4p8tfdx88h0000gn/T/ipykernel_64960/2792279686.py:15: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/b/PT%20Bl%C3%BCmchenschirmFrau%2001k.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/b/PT%20Berlin%20Koffermensch%2001t.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/b/PT%20Blue%20Lady%2001s.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/a/PT%20Pioneer%20Akira%20Building%2001t.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/a/PT%20Avatar-AlienAttack%2004k.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/a/PT%20Avianca%20plane%2003t.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/a/PT%20AviatorilorColumn%2001s.png
# https://eboy.s3-us-west-1.amazonaws.com/bubble/parts/a/PT%20MIA%20Airport%20West%20Layer%2002k.png
# ...
